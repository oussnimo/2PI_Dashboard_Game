# %%
i want a diagrame for this (SLIDE 5 — Teacher Flow
Heading: How a Teacher Creates a Quiz

Login → Dashboard → "Create New Quiz"
Fill: Course, Topic, Game Number, Number of Levels
Choose: Manual (level by level) OR AI Generation
Review in Preview → Save to database
Export as SCORM ZIP → Upload to LMS
🎨 Visual suggestion: Numbered step timeline with icons
)
